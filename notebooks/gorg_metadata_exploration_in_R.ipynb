# %%
library('tidyverse')
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.1     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.1     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.1
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
df <- read_csv("/mnt/storage/data/sag-data/gorg-dark//SAG_summary_20221107.csv")
# Out:
# Warning message:
# “One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)”
# Rows: 9178 Columns: 46
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (18): SAG, field_sample_PI, geographic_region, expedition, station_name...
# dbl  (17): latitude, longitude, cell_diameter_µm, X572.27_488, X692.40_488, ...
# num  (10): side_scatter, forward_scatter, X531.40_488, trigger_pulse_width, ...
# date  (1): FACS_date
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
head(df)
# Out:
#   SAG        field_sample_PI geographic_region expedition   station_name
# 1 AG-538-A01 Herndl & Sintes North Atlantic    Archimedes-4 17
# 2 AG-538-A02 Herndl & Sintes North Atlantic    Archimedes-4 17
# 3 AG-538-A04 Herndl & Sintes North Atlantic    Archimedes-4 17
# 4 AG-538-A05 Herndl & Sintes North Atlantic    Archimedes-4 17
# 5 AG-538-A07 Herndl & Sintes North Atlantic    Archimedes-4 17
# 6 AG-538-A08 Herndl & Sintes North Atlantic    Archimedes-4 17
#   field_sample latitude longitude depth field_collection_date ⋯
# 1 97A          18       -41       553   2010-10-26            ⋯
# 2 97A          18       -41       553   2010-10-26            ⋯
# 3 97A          18       -41       553   2010-10-26            ⋯
# 4 97A          18       -41       553   2010-10-26            ⋯
# 5 97A          18       -41       553   2010-10-26            ⋯
# 6 97A          18       -41       553   2010-10-26            ⋯
#   gtdb_classification
# ...

# %%
nrow(df) %>% paste0('There are ', ., ' SAGs described in GORG-Dark_v1') %>% print
# Out:
# [1] "There are 9178 SAGs described in GORG-Dark_v1"

# %%
options(repr.plot.width=12, repr.plot.height=8)

ggplot(data = df, mapping = aes(x = geographic_region)) +
    geom_bar() + theme(axis.text.x = element_text(angle = 90, vjust = 0.5, hjust=1, size = 12))
# Out:
# plot without title
